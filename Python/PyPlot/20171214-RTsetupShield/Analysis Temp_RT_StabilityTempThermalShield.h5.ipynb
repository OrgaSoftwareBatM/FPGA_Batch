# %%
# %matplotlib inline
from analysis import spec
data = spec(fname='Temp_RT_StabilityTempThermalShield.h5')
for i, read in enumerate(data.readouts['units']):
    data.plot1D(figNo=i+1, readouts=[i], x=[0,750], counter=True, xlabel='time (min)')
# Out:
# Selected range is larger than sweep dimensions.
# Selected range is larger than sweep dimensions.
# Selected range is larger than sweep dimensions.
# Selected range is larger than sweep dimensions.
# Selected range is larger than sweep dimensions.
# Selected range is larger than sweep dimensions.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3239: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=14.998426, top=14.998426
#   'bottom=%s, top=%s') % (bottom, top))
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3239: UserWarning: Attempting to set identical bottom==top results
# ...
