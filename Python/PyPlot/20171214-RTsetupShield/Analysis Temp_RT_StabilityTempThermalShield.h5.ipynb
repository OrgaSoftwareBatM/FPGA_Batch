# %%
# %matplotlib inline
from analysis import spec
data = spec(fname='Temp_RT_StabilityTempThermalShield.h5')
data.plot1D(figNo=1, readouts=[1], xaxisRange=[0,23], xfactor=0.01666666666666667, yaxisRange=[112,120], counter=True, xlabel='time (h)')
data.plot1D(figNo=2, readouts=[5], xaxisRange=[0,23], xfactor=0.01666666666666667, yaxisRange=[0.395,0.397], counter=True, xlabel='time (h)')
# Out:
# apply X factor
# apply X factor

# %%
# %matplotlib inline
from analysis import spec
data2 = spec(fname='Temp_201712141200.h5')
data2.plot1D(figNo=3, readouts=[1], xaxisRange=[0,12], xfactor=0.01666666666666667, yaxisRange=[112,120], counter=True, xlabel='time (h)')
data2.plot1D(figNo=4, readouts=[5], xaxisRange=[0,12], xfactor=0.01666666666666667, yaxisRange=[0.395,0.397], counter=True, xlabel='time (h)')
# Out:
# apply X factor
# apply X factor
