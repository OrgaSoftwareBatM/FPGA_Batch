# %%
from analysis import spec
# %matplotlib inline
data = spec(fname='Temp_RT_StabilityTempThermalShield.h5')
start = 'Start NF Amp in Polystyrene'
data.plot1D(figNo=1, readouts=[1], xaxisRange=[0,23], ylaw=True, 
yaxisRange=[32,50], xfactor=1/60.0, counter=True, 
ylabel=r'$T_{PT100}$ ($\°$ C)',xlabel='time (h)', title=start)
data.plot1D(figNo=2, readouts=[5], xaxisRange=[0,23], 
xfactor=1/60.0, yaxisRange=[395,397], counter=True, 
yfactor=1000.0,ylabel=r'$g_{NF}$',xlabel='time (h)', title=start)

# %%
from analysis import spec
data2 = spec(fname='Temp_201712141200.h5')
day = 'After 1day NF Amp in Polystyrene'
data2.plot1D(figNo=3, readouts=[1], xaxisRange=[0,12], 
ylaw=True, yaxisRange=[46,49], xfactor=1/60.0, 
counter=True, ylabel=r'$T_{PT100}$ ($\°$ C)',xlabel='time (h)', title=day)
data2.plot1D(figNo=4, readouts=[5], xaxisRange=[0,12], 
xfactor=1/60.0, yaxisRange=[395.5,396.5], 
counter=True, yfactor=1000.0,
ylabel=r'$g_{NF}$',xlabel='time (h)',title=day)
