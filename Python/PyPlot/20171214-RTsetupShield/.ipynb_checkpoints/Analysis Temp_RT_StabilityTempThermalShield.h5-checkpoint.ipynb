# %%
# %matplotlib inline
from analysis import spec
data = spec(fname='Temp_RT_StabilityTempThermalShield.h5')
data.plot1D(figNo=1, readouts=[1], xaxisRange=[0,1400], xfactor=0.01666666666666667, yaxisRange=[112,120], counter=True, xlabel='time (h)')
data.plot1D(figNo=2, readouts=[5], xaxisRange=[0,1400], xfactor=0.01666666666666667, yaxisRange=[0.395,0.402], counter=True, xlabel='time (h)')
