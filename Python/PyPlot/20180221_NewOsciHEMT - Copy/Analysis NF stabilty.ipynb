# %%
from analysis import spec
# %matplotlib inline
data = spec(fname='Temp_201802211752.h5')
start = 'NFamp HEMT with Lock_In and Stanford Research Osci'
xrange = []
data.plot1D(figNo=1, readouts=[0], ylaw=True, 
yaxisRange=[24,32], xlabel='time (h)',xaxisRange=xrange, 
xfactor=1/60.0,
ylabel=r'$T_{PT100}$ ($\°$ C)', title=start)
data.plot1D(figNo=2, readouts=[3], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[99.8,100.15], counter=True, 
yfactor=1/0.7117*100,ylabel=r'$R_{HEMT+NF Gain at Lock_In}(\%)$',xlabel='time (h)', title=start)
# Out:
# Selected axis is not swept: Xmin = Xmax = 60000.000000 --> useCounter

# %%
#from analysis import spec
#%matplotlib inline
#data = spec(fname='201802151056.h5')
#for i, read in enumerate(data.readouts['units']):
#    data.plot1D(figNo=i+1, readouts=[i], counter=True, xlabel='time (h)',xaxisRange=[], xfactor=1/60.0)
