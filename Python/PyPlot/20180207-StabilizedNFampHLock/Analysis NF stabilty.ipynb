# %%
from analysis import spec
# %matplotlib inline
data = spec(fname='201802061615.h5')
start = 'NF'
xrange = []
data.plot1D(figNo=1, readouts=[1], ylaw=True, 
yaxisRange=[17,30], xlabel='time (h)',xaxisRange=xrange, 
xfactor=1/60.0,
ylabel=r'$T_{PT100}$ ($\°$ C)', title=start)
data.plot1D(figNo=2, readouts=[5], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[6.20,6.21], counter=True, 
yfactor=1000,ylabel=r'$R_{LockInHEMT}(mV)$',xlabel='time (h)', title=start)
data.plot1D(figNo=3, readouts=[2], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[], counter=True, 
yfactor=1,ylabel=r'$V_{SourceAtHP}(V)$',xlabel='time (h)', title=start)
data.plot1D(figNo=4, readouts=[0], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[], counter=True, 
yfactor=1,ylabel=r'$V_{DrainAtK}(V)$',xlabel='time (h)', title=start)
# Out:
# Selected axis is not swept: Xmin = Xmax = 60000.000000 --> useCounter
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-7f76544cb643> in <module>()
#      10 data.plot1D(figNo=2, readouts=[5], xaxisRange=xrange,
#      11 xfactor=1/60.0, yaxisRange=[6.20,6.21], counter=True,
# ---> 12 yfactor=1000,ylabel=r'$R_{LockInHEMT}(mV)$',xlabel='time (h)', title=start)
#      13 data.plot1D(figNo=3, readouts=[2], xaxisRange=xrange,
#      14 xfactor=1/60.0, yaxisRange=[], counter=True,
#
# ~\Documents\GitHub\FPGA_Batch\Python\PyPlot\20180207-StabilizedNFampHLock\analysis.py in plot1D(self, *args, **kwargs)
#     778                 else:
#     779                     read = i
# --> 780             d = self.readouts['data'][read,Ellipsis][tuple(plotrange)]      # Get data
#     781             d = np.multiply(d, yfactor) # Apply factor for data
#     782             try:
#
# IndexError: index 5 is out of bounds for axis 0 with size 4

# %%
from analysis import spec
# %matplotlib inline
data = spec(fname='201802061615.h5')
for i, read in enumerate(data.readouts['units']):
    data.plot1D(figNo=i+1, readouts=[i], counter=True, xlabel='time (h)',xaxisRange=[], xfactor=1/60.0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3239: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   'bottom=%s, top=%s') % (bottom, top))
