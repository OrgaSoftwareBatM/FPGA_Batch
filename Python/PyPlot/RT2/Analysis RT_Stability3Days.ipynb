# %%
# %matplotlib inline
from analysis import spec
data = spec(fname='RT_Stability3Days.h5')
for i, read in enumerate(data.readouts['units']):
    data.plot1D(figNo=2, readouts=[i], counter=True, xlabel='time (min)', clear=False)
