# %%
from analysis import spec
# %matplotlib inline
data = spec(fname='201801220853.h5')
start = '2 Days'
xrange = []
data.plot1D(figNo=1, readouts=[1], ylaw=True, 
yaxisRange=[17,30], xlabel='time (h)',xaxisRange=xrange, 
xfactor=1/60.0,
ylabel=r'$T_{PT100}$ ($\°$ C)', title=start)
data.plot1D(figNo=2, readouts=[5], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[98.8,100.2], counter=True, 
yfactor=1/0.403*100,ylabel=r'$g_{NF}(\%)$',xlabel='time (h)', title=start)
data.plot1D(figNo=3, readouts=[2], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[099.9987,100.0012], counter=True, 
yfactor=1/14.99915*100,ylabel=r'$V_{NFatK}(\%)$',xlabel='time (h)', title=start)
data.plot1D(figNo=3, readouts=[0], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[099.9987,100.0012], counter=True, 
yfactor=1/15.13085*100,ylabel=r'$V_{NFatHP}(\%)$',xlabel='time (h)', title=start)
data.plot1D(figNo='3', readouts=[0], xaxisRange=xrange, 
xfactor=1/60.0, yaxisRange=[099.99975,100.0002], counter=True, 
yfactor=1/15.13086*100,ylabel=r'$V_{NFatHP}(\%)$',xlabel='time (h)', title=start)
# Out:
# Selected axis is not swept: Xmin = Xmax = 55000.000000 --> useCounter

# %%
#from analysis import spec
#data = spec(fname='Temp_20180119_RTstabilzed.h5')
#for i, read in enumerate(data.readouts['units']):
#    data.plot1D(figNo=i+1, readouts=[i], counter=True, xlabel='time (h)',xaxisRange=[0,27], 
#xfactor=1/60.0)
