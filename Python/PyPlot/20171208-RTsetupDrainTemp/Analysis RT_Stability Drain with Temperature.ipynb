# %%
# %matplotlib inline
from analysis import spec
data = spec(fname='RT_StabilityTempDrain.h5')
for i, read in enumerate(data.readouts['units']):
    data.plot1D(figNo=i+1, readouts=[i], counter=True, xlabel='time (min)')
